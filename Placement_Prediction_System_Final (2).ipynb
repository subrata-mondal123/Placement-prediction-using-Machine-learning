# %%
data = pd.read_csv('Placement_Data.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
data.tail()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 9995                No         85         66       NotPlaced
# ...

# %%
import pandas as pd

# %%
data.shape
# Out:
# (10000, 12)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 10000
# Number of Columns 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
data.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# dtype: int64

# %%
data.describe()
# Out:
#          StudentID          CGPA   Internships      Projects  \
# count  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      7.698010      1.049200      2.026600
# std     2886.89568      0.640131      0.665901      0.867968
# min        1.00000      6.500000      0.000000      0.000000
# 25%     2500.75000      7.400000      1.000000      1.000000
# 50%     5000.50000      7.700000      1.000000      2.000000
# 75%     7500.25000      8.200000      1.000000      3.000000
# max    10000.00000      9.100000      2.000000      3.000000
#
#        Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count              10000.000000       10000.000000      10000.000000
# mean                   1.013200          79.449900          4.323960
# std                    0.904272           8.159997          0.411622
# min                    0.000000          60.000000          3.000000
# ...

# %%
data.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
data['PlacementStatus'].value_counts()
# Out:
# NotPlaced    5803
# Placed       4197
# Name: PlacementStatus, dtype: int64

# %%
data.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
data[(data['PlacementTraining']=="No") & (data['PlacementStatus']=="Placed")].head()
# Out:
#      StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 45          46   6.7            1         1                         2
# 65          66   8.0            0         3                         0
# 97          98   7.8            2         2                         2
# 113        114   8.6            2         3                         0
# 122        123   7.7            1         3                         2
#
#      AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 45                  73               4.5                        No
# 65                  68               4.2                       Yes
# 97                  90               4.8                       Yes
# 113                 81               4.7                       Yes
# 122                 90               4.8                       Yes
#
#     PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 45                 No         55         66          Placed
# ...

# %%
data.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
data = data.drop(['StudentID'],axis=1)

# %%
data.head(1)
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
#
#    SoftSkillsRating ExtracurricularActivities PlacementTraining  SSC_Marks  \
# 0               4.4                        No                No         61
#
#    HSC_Marks PlacementStatus
# 0         79       NotPlaced

# %%
data['PlacementTraining'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['PlacementTraining'] = data['PlacementTraining'].map({'No':0,'Yes':1})

# %%
data.head(2)
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
#
#    SoftSkillsRating ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                        No                  0         61
# 1               4.0                       Yes                  1         78
#
#    HSC_Marks PlacementStatus
# 0         79       NotPlaced
# 1         82          Placed

# %%
data['ExtracurricularActivities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['ExtracurricularActivities'] = data['ExtracurricularActivities'].map({'No':0,'Yes':1})

# %%
data.head(2)
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
#
#    SoftSkillsRating  ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                          0                  0         61
# 1               4.0                          1                  1         78
#
#    HSC_Marks PlacementStatus
# 0         79       NotPlaced
# 1         82          Placed

# %%
data['PlacementStatus'].unique()
# Out:
# array(['NotPlaced', 'Placed'], dtype=object)

# %%
data['PlacementStatus'] = data['PlacementStatus'].map({'NotPlaced':0,'Placed':1})

# %%
data.head()
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating  ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                          0                  0         61
# 1               4.0                          1                  1         78
# 2               4.8                          1                  0         79
# 3               4.4                          1                  1         81
# 4               4.5                          1                  1         74
#
#    HSC_Marks  PlacementStatus
# ...

# %%
data.columns
# Out:
# Index(['CGPA', 'Internships', 'Projects', 'Workshops/Certifications',
#        'AptitudeTestScore', 'SoftSkillsRating', 'ExtracurricularActivities',
#        'PlacementTraining', 'SSC_Marks', 'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
X = data.drop('PlacementStatus',axis=1)
y= data['PlacementStatus']

# %%
X
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 0      7.5            1         1                         1
# 1      8.9            0         3                         2
# 2      7.3            1         2                         2
# 3      7.5            1         1                         2
# 4      8.3            1         2                         2
# ...    ...          ...       ...                       ...
# 9995   7.5            1         1                         2
# 9996   7.4            0         1                         0
# 9997   8.4            1         3                         0
# 9998   8.9            0         3                         2
# 9999   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating  ExtracurricularActivities  \
# 0                    65               4.4                          0
# 1                    90               4.0                          1
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    0
# Name: PlacementStatus, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
data.head()
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating  ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                          0                  0         61
# 1               4.0                          1                  1         78
# 2               4.8                          1                  0         79
# 3               4.4                          1                  1         81
# 4               4.5                          1                  1         74
#
#    HSC_Marks  PlacementStatus
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)

svm = SVC()
svm.fit(X_train,y_train)

knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)

rf=RandomForestClassifier()
rf.fit(X_train,y_train)

gb=GradientBoostingClassifier()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = knn.predict(X_test)
y_pred4 = dt.predict(X_test)
y_pred5 = rf.predict(X_test)
y_pred6 = gb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score1=accuracy_score(y_test,y_pred1)
score2=accuracy_score(y_test,y_pred2)
score3=accuracy_score(y_test,y_pred3)
score4=accuracy_score(y_test,y_pred4)
score5=accuracy_score(y_test,y_pred5)
score6=accuracy_score(y_test,y_pred6)

# %%
print(score1,score2,score3,score4,score5,score6)
# Out:
# 0.791 0.779 0.758 0.722 0.7845 0.791

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF','GB'],
            'ACC':[score1*100,
                  score2*100,
                  score3*100,
                  score4*100,
                  score5*100,score6*100]})

# %%
final_data
# Out:
#   Models    ACC
# 0     LR  79.10
# 1    SVC  77.90
# 2    KNN  75.80
# 3     DT  72.20
# 4     RF  78.45
# 5     GB  79.10

# %%
import seaborn as sns

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %%
new_data = pd.DataFrame({
    'CGPA':7.5,
    'Internships':1,
    'Projects':1,
    'Workshops/Certifications':1,
    'AptitudeTestScore':65,
    'SoftSkillsRating':4.4,
    'ExtracurricularActivities':0,
    'PlacementTraining':0,
    'SSC_Marks':61,
    'HSC_Marks':79,   
},index=[0])

# %%
lr= LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
p=lr.predict(new_data)
prob=lr.predict_proba(new_data)
if p==1:
    print('Placed')
    print(f"You will be placed with probability of {prob[0][1]:.2f}")
else:
    print("Not-placed")
# Out:
# Not-placed

# %%
prob
# Out:
# array([[0.96403548, 0.03596452]])

# %%
import joblib

# %%
joblib.dump(lr,'model_campus_placement')
# Out:
# ['model_campus_placement']

# %%
model = joblib.load('model_campus_placement')

# %%
model.predict(new_data)
# Out:
# array([0], dtype=int64)

# %%
from tkinter import *
import joblib
import numpy as np
import tkinter.font as font
import pandas as pd

def show_entry_fields():
    p1 = float(e1.get())
    p2 = int(e2.get())
    p3 = int(e3.get())
    p4 = int(e4.get())
    p5 = int(e5.get())
    p6 = float(e6.get())
    text = clicked.get()
    if text == "Yes":
        p7 = 1
    else:
        p7 = 0
    text = clicked1.get()
    if text == "Yes":
        p8 = 1
    else:
        p8 = 0
    p9 = float(e9.get())
    p10 = float(e10.get())
    

    model = joblib.load('model_campus_placement')
    new_data = pd.DataFrame({
        'CGPA': p1,
        'Internships': p2,
        'Projects': p3,
        'Workshops/Certifications': p4,
        'AptitudeTestScore': p5,
        'SoftSkillsRating': p6,
        'ExtracurricularActivities': p7,
        'PlacementTraining': p8,
        'SSC_Marks': p9,
        'HSC_Marks': p10
    }, index=[0])
    
    result = model.predict(new_data)
    result1 = model.predict_proba(new_data)
    
    if result[0] == 0:
        Label(master, text="Not Placed").grid(row=31)
    else:
        Label(master, text="Placed with Probability of", font=("Arial", 15)).grid(row=31)
        Label(master, text=round(result1[0][1], 2) * 100, font=("Arial", 15)).grid(row=33)
        Label(master, text="Percent", font=("Arial", 15)).grid(row=34)

master = Tk()
master.title("Campus Placement Prediction System")

label = Label(master, text="Campus Placement Prediction System", bg="green", fg="white", font=("Arial", 20)).grid(row=0, columnspan=2)

Label(master, text="CGPA", font=("Arial", 15)).grid(row=1)
Label(master, text="Internships", font=("Arial", 15)).grid(row=2)
Label(master, text="Projects", font=("Arial", 15)).grid(row=3)
Label(master, text="Workshops/Certifications", font=("Arial", 15)).grid(row=4)
Label(master, text="Aptitude Test Score", font=("Arial", 15)).grid(row=5)
Label(master, text="Soft Skills Rating", font=("Arial", 15)).grid(row=6)
Label(master, text="Extracurricular Activities", font=("Arial", 15)).grid(row=7)
Label(master, text="Placement Training", font=("Arial", 15)).grid(row=8)
Label(master, text="SSC Marks", font=("Arial", 15)).grid(row=9)
Label(master, text="HSC Marks", font=("Arial", 15)).grid(row=10)

clicked = StringVar()
options = ["Yes", "No"]
clicked1 = StringVar()
options1 = ["Yes", "No"]

e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = OptionMenu(master, clicked, *options)
e7.configure(width=13)
e8 = OptionMenu(master, clicked1, *options1)
e8.configure(width=13)
e9 = Entry(master)
e10 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10, column=1)

buttonFont = font.Font(family='Helvetica', size=16, weight='bold')
Button(master, text='Predict', height=1, width=8, activebackground='#00ff00', font=buttonFont, bg='black', fg='white', command=show_entry_fields).grid()

mainloop()
